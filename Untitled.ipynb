# %%
from scheduler_class import *


def main():
    dis_server = Distribution()
    line = Line(5)
    server = Server(dis_server, line)
    line2 = Line(4)
    ser2 = Server(dis_server, line2)
    ph = Phase()
    ph.addServer(server, 0.3)
    ph.addServer(ser2, 0.7)
    ph.set_probability()

    server_dist = Distribution('gamma', [4, 2])
    line3 = Line(9)
    ser3 = Server(server_dist, line3)
    line4 = Line(10)
    ser4 = Server(server_dist, line4)
    ph2 = Phase()
    ph2.addServer(ser3, 0.5)
    ph2.addServer(ser4, 0.5)
    ph2.set_probability()

    create_dis = Distribution('normal', [5, 0.1])
    create = Create(create_dis)
    env = Environment(create)
    env.add_phase(ph)
    env.add_phase(ph2)
    env.set_stop(30)
    sch = Scheduler(env)
    sch.start()
    in_list = sch.get_output()
    st = sch.get_statistics()

    create2 = Create(create_dis, in_list,5)
    env2 = Environment(create2)
    env2.add_phase(ph)
    env2.add_phase(ph2)
    env2.set_stop(30)
    sch2 = Scheduler(env2, in_list[0][0],st)
    sch2.start()
    sch2.get_statistics().sort_entity()

    num = 5
    #print "probaility of "+ num + "entity in system :",sch2.get_statistics().get_p_n(num)
    print "w_n :",sch2.get_statistics().get_w_n(3)
    print "l_t :",sch2.get_statistics().get_l_t(3)
    sch2.get_statistics().plot_num_entity_time()
    st.plot_server([server, ser2, ser3, ser4], ['server_1', 'server_2', 'server_3', 'server_4'])
main()
# Out:
# in start_event
# <phase_class.Phase instance at 0x00000000088082C8>
# 0
# set arrival event
# en in create:  <entity_class.Entity instance at 0x00000000088031C8>
# event_type  A  event: (0, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000088031C8>)
# en in create:  <entity_class.Entity instance at 0x00000000087FADC8>
# -------------event-------------
# time:  4
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  0
# event_type  D  event: (4, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000088031C8>)
# -------------event-------------
# time:  4
# type:  A
# phase:  2
# server:  0
# customer:  0
# event_type  A  event: (4, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000088031C8>)
# en in create:  <entity_class.Entity instance at 0x00000000087FAE08>
# -------------event-------------
# time:  10
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  0
# event_type  A  event: (4, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FADC8>)
# en in create:  <entity_class.Entity instance at 0x00000000087FAD08>
# -------------event-------------
# time:  7
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  1
# event_type  D  event: (7, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FADC8>)
# -------------event-------------
# time:  7
# type:  A
# phase:  2
# server:  0
# customer:  1
# event_type  A  event: (7, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FADC8>)
# en in create:  <entity_class.Entity instance at 0x00000000087FAC88>
# -------------event-------------
# time:  16
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  1
# event_type  A  event: (8, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAD08>)
# en in create:  <entity_class.Entity instance at 0x00000000087FA408>
# -------------event-------------
# time:  11
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  3
# event_type  A  event: (9, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAE08>)
# en in create:  <entity_class.Entity instance at 0x0000000008810288>
# -------------event-------------
# time:  16
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  2
# event_type  D  event: (10, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000088031C8>)
# -------------event-------------
# time:  10
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  0
# event_type  D  event: (11, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FAD08>)
# -------------event-------------
# time:  11
# type:  A
# phase:  2
# server:  0
# customer:  3
# event_type  A  event: (11, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAD08>)
# en in create:  <entity_class.Entity instance at 0x00000000087FAD48>
# -------------event-------------
# time:  25
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  3
# event_type  A  event: (12, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAC88>)
# en in create:  <entity_class.Entity instance at 0x00000000087E0D08>
# -------------event-------------
# time:  14
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  4
# event_type  A  event: (12, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FA408>)
# en in create:  <entity_class.Entity instance at 0x00000000087E0C88>
# -------------event-------------
# time:  19
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  5
# event_type  A  event: (14, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008810288>)
# en in create:  <entity_class.Entity instance at 0x00000000087E0E08>
# -------------event-------------
# time:  18
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  6
# event_type  D  event: (14, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FAC88>)
# -------------event-------------
# time:  14
# type:  A
# phase:  2
# server:  0
# customer:  4
# event_type  A  event: (14, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAC88>)
# en in create:  <entity_class.Entity instance at 0x00000000087E08C8>
# -------------event-------------
# time:  20
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  4
# event_type  A  event: (15, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAD48>)
# en in create:  <entity_class.Entity instance at 0x00000000087E0108>
# -------------event-------------
# time:  19
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  7
# event_type  D  event: (16, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087FADC8>)
# -------------event-------------
# time:  16
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  1
# event_type  D  event: (16, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000087FAE08>)
# -------------event-------------
# time:  16
# type:  A
# phase:  2
# server:  0
# customer:  2
# event_type  A  event: (16, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAE08>)
# en in create:  <entity_class.Entity instance at 0x00000000087E0F08>
# -------------event-------------
# time:  31
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  2
# event_type  A  event: (17, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0C88>)
# en in create:  <entity_class.Entity instance at 0x000000000880FA48>
# -------------event-------------
# time:  22
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  9
# event_type  A  event: (17, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0D08>)
# en in create:  <entity_class.Entity instance at 0x000000000880F888>
# -------------event-------------
# time:  19
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  8
# event_type  D  event: (18, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x0000000008810288>)
# -------------event-------------
# time:  18
# type:  A
# phase:  2
# server:  0
# customer:  6
# event_type  A  event: (18, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x0000000008810288>)
# en in create:  <entity_class.Entity instance at 0x000000000880F7C8>
# -------------event-------------
# time:  21
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  6
# event_type  A  event: (19, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E08C8>)
# en in create:  <entity_class.Entity instance at 0x000000000880F808>
# -------------event-------------
# time:  21
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  11
# event_type  D  event: (19, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E0D08>)
# -------------event-------------
# time:  19
# type:  A
# phase:  2
# server:  0
# customer:  8
# event_type  A  event: (19, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0D08>)
# en in create:  <entity_class.Entity instance at 0x000000000880DAC8>
# -------------event-------------
# time:  28
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  8
# event_type  A  event: (19, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0E08>)
# en in create:  <entity_class.Entity instance at 0x000000000880DF88>
# -------------event-------------
# time:  23
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  10
# event_type  D  event: (19, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000087FAD48>)
# -------------event-------------
# time:  19
# type:  A
# phase:  2
# server:  0
# customer:  7
# event_type  D  event: (19, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FA408>)
# -------------event-------------
# time:  19
# type:  A
# phase:  2
# server:  0
# customer:  5
# event_type  A  event: (19, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAD48>)
# en in create:  <entity_class.Entity instance at 0x0000000008A00E88>
# -------------event-------------
# time:  27
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  7
# event_type  A  event: (19, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FA408>)
# en in create:  <entity_class.Entity instance at 0x0000000008A00BC8>
# -------------event-------------
# time:  30
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  5
# event_type  A  event: (20, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0108>)
# en in create:  <entity_class.Entity instance at 0x0000000008A00C08>
# -------------event-------------
# time:  26
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  12
# event_type  D  event: (20, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x00000000087FAC88>)
# -------------event-------------
# time:  20
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  4
# event_type  D  event: (21, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E08C8>)
# -------------event-------------
# time:  21
# type:  A
# phase:  2
# server:  0
# customer:  11
# event_type  A  event: (21, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E08C8>)
# en in create:  <entity_class.Entity instance at 0x0000000008A05748>
# -------------event-------------
# time:  24
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  11
# event_type  D  event: (21, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x0000000008810288>)
# -------------event-------------
# time:  21
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  6
# event_type  A  event: (21, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880F888>)
# en in create:  <entity_class.Entity instance at 0x00000000087FA3C8>
# -------------event-------------
# time:  25
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  15
# event_type  A  event: (21, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0F08>)
# en in create:  <entity_class.Entity instance at 0x00000000087E02C8>
# -------------event-------------
# time:  26
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  13
# event_type  D  event: (22, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000087E0C88>)
# -------------event-------------
# time:  22
# type:  A
# phase:  2
# server:  0
# customer:  9
# event_type  A  event: (22, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880FA48>)
# en in create:  <entity_class.Entity instance at 0x00000000087E0E88>
# -------------event-------------
# time:  24
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  14
# event_type  A  event: (22, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0C88>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08248>
# -------------event-------------
# time:  27
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  9
# event_type  D  event: (23, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E0E08>)
# -------------event-------------
# time:  23
# type:  A
# phase:  2
# server:  0
# customer:  10
# event_type  A  event: (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880F808>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08188>
# -------------event-------------
# time:  29
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  17
# event_type  A  event: (23, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0E08>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08308>
# -------------event-------------
# time:  25
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  10
# event_type  A  event: (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880F7C8>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08388>
# -------------event-------------
# time:  25
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  16
# event_type  A  event: (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A00BC8>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08408>
# -------------event-------------
# time:  25
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  21
# event_type  A  event: (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880DF88>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08488>
# -------------event-------------
# time:  30
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  19
# event_type  A  event: (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A00E88>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08508>
# -------------event-------------
# time:  30
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  20
# event_type  D  event: (24, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x000000000880FA48>)
# -------------event-------------
# time:  24
# type:  A
# phase:  2
# server:  0
# customer:  14
# event_type  A  event: (24, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880DAC8>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08588>
# -------------event-------------
# time:  26
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  18
# event_type  A  event: (24, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880FA48>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08648>
# -------------event-------------
# time:  34
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  14
# event_type  A  event: (24, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A00C08>)
# en in create:  <entity_class.Entity instance at 0x0000000008A086C8>
# -------------event-------------
# time:  28
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  22
# event_type  D  event: (24, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x00000000087E08C8>)
# -------------event-------------
# time:  24
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  11
# event_type  D  event: (25, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087FAD08>)
# -------------event-------------
# time:  25
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  3
# event_type  D  event: (25, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x000000000880F888>)
# -------------event-------------
# time:  25
# type:  A
# phase:  2
# server:  0
# customer:  15
# event_type  A  event: (25, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880F888>)
# en in create:  <entity_class.Entity instance at 0x0000000008A05208>
# -------------event-------------
# time:  29
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  15
# event_type  D  event: (25, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087E0E08>)
# -------------event-------------
# time:  25
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  10
# event_type  D  event: (25, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x000000000880F7C8>)
# -------------event-------------
# time:  25
# type:  A
# phase:  2
# server:  0
# customer:  16
# event_type  A  event: (25, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880F7C8>)
# en in create:  <entity_class.Entity instance at 0x00000000087FAD88>
# -------------event-------------
# time:  37
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  16
# event_type  D  event: (25, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x0000000008A00BC8>)
# -------------event-------------
# time:  25
# type:  A
# phase:  2
# server:  0
# customer:  21
# event_type  A  event: (25, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x0000000008A00BC8>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08788>
# -------------event-------------
# time:  35
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  21
# event_type  A  event: (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E02C8>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08808>
# -------------event-------------
# time:  29
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  25
# event_type  A  event: (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FA3C8>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08888>
# -------------event-------------
# time:  32
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  24
# event_type  D  event: (26, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x000000000880DAC8>)
# -------------event-------------
# time:  26
# type:  A
# phase:  2
# server:  0
# customer:  18
# event_type  A  event: (26, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880DAC8>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08908>
# -------------event-------------
# time:  30
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  18
# event_type  D  event: (26, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E0F08>)
# -------------event-------------
# time:  26
# type:  A
# phase:  2
# server:  0
# customer:  13
# event_type  A  event: (26, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0F08>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08988>
# -------------event-------------
# time:  31
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  13
# event_type  D  event: (26, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E0108>)
# -------------event-------------
# time:  26
# type:  A
# phase:  2
# server:  0
# customer:  12
# event_type  A  event: (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A05748>)
# en in create:  <entity_class.Entity instance at 0x0000000008AD0388>
# -------------event-------------
# time:  32
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  23
# event_type  A  event: (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08248>)
# en in create:  <entity_class.Entity instance at 0x00000000087E0B88>
# -------------event-------------
# time:  32
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  27
# event_type  A  event: (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0E88>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08A48>
# -------------event-------------
# time:  30
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  26
# event_type  A  event: (26, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0108>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08A88>
# -------------event-------------
# time:  30
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  12
# event_type  D  event: (27, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087E0C88>)
# -------------event-------------
# time:  27
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  9
# event_type  D  event: (27, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x00000000087FAD48>)
# -------------event-------------
# time:  27
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  7
# event_type  A  event: (27, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08408>)
# en in create:  <entity_class.Entity instance at 0x000000000880FA08>
# -------------event-------------
# time:  31
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  31
# event_type  A  event: (27, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08488>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08B08>
# -------------event-------------
# time:  32
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  32
# event_type  D  event: (28, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087E0D08>)
# -------------event-------------
# time:  28
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  8
# event_type  D  event: (28, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x0000000008A00C08>)
# -------------event-------------
# time:  28
# type:  A
# phase:  2
# server:  0
# customer:  22
# event_type  A  event: (28, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x0000000008A00C08>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08BC8>
# -------------event-------------
# time:  30
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  22
# event_type  A  event: (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08188>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08C88>
# -------------event-------------
# time:  30
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  28
# event_type  A  event: (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08308>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08D08>
# -------------event-------------
# time:  33
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  29
# event_type  A  event: (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08388>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08D88>
# -------------event-------------
# time:  30
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  30
# event_type  A  event: (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08508>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08E08>
# -------------event-------------
# time:  31
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  33
# event_type  A  event: (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08588>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08E88>
# -------------event-------------
# time:  30
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  34
# event_type  A  event: (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A086C8>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08F08>
# -------------event-------------
# time:  31
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  36
# event_type  D  event: (29, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x000000000880F808>)
# -------------event-------------
# time:  29
# type:  A
# phase:  2
# server:  0
# customer:  17
# event_type  D  event: (29, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x000000000880F888>)
# -------------event-------------
# time:  29
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  15
# event_type  D  event: (29, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E02C8>)
# -------------event-------------
# time:  29
# type:  A
# phase:  2
# server:  0
# customer:  25
# event_type  A  event: (29, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E02C8>)
# en in create:  <entity_class.Entity instance at 0x00000000087E0248>
# -------------event-------------
# time:  30
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  25
# event_type  A  event: (29, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08648>)
# en in create:  <entity_class.Entity instance at 0x0000000008A08FC8>
# -------------event-------------
# time:  31
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  35
# event_type  A  event: (29, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880F808>)
# en in create:  <entity_class.Entity instance at 0x0000000008A00C88>
# -------------event-------------
# time:  47
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  17
# event_type  A  event: (29, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08788>)
# en in create:  <entity_class.Entity instance at 0x0000000008AD0048>
# -------------event-------------
# time:  35
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  39
# event_type  S  event: (30, 'S', 0, 0)
# in start_event
# <phase_class.Phase instance at 0x00000000088082C8>
# 0
# set arrival event
# en in create:  <entity_class.Entity instance at 0x00000000088031C8>
# event_type  A  event: (10, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000088031C8>)
# en in create:  <entity_class.Entity instance at 0x00000000087FADC8>
# -------------event-------------
# time:  17
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  0
# event_type  A  event: (14, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FADC8>)
# en in create:  <entity_class.Entity instance at 0x00000000087FAC88>
# -------------event-------------
# time:  17
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  1
# event_type  D  event: (17, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000088031C8>)
# -------------event-------------
# time:  17
# type:  A
# phase:  2
# server:  0
# customer:  0
# event_type  A  event: (17, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000088031C8>)
# en in create:  <entity_class.Entity instance at 0x0000000008810288>
# -------------event-------------
# time:  20
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  0
# event_type  D  event: (17, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FADC8>)
# -------------event-------------
# time:  17
# type:  A
# phase:  2
# server:  0
# customer:  1
# event_type  A  event: (17, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FADC8>)
# en in create:  <entity_class.Entity instance at 0x00000000087E08C8>
# -------------event-------------
# time:  25
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  1
# event_type  A  event: (18, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAC88>)
# -------------event-------------
# time:  25
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  4
# event_type  D  event: (20, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000088031C8>)
# -------------event-------------
# time:  20
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  0
# event_type  A  event: (22, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008810288>)
# -------------event-------------
# time:  28
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x0000000008808548>
# customer:  6
# event_type  A  event: (22, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E08C8>)
# -------------event-------------
# time:  28
# type:  D
# phase:  1
# server:  <server_class.Server instance at 0x000000000881CBC8>
# customer:  11
# event_type  D  event: (25, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FAC88>)
# -------------event-------------
# time:  25
# type:  A
# phase:  2
# server:  0
# customer:  4
# event_type  A  event: (25, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAC88>)
# -------------event-------------
# time:  45
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  4
# event_type  D  event: (25, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087FADC8>)
# -------------event-------------
# time:  25
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  1
# event_type  D  event: (28, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x0000000008810288>)
# -------------event-------------
# time:  28
# type:  A
# phase:  2
# server:  0
# customer:  6
# event_type  D  event: (28, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000087E08C8>)
# -------------event-------------
# time:  28
# type:  A
# phase:  2
# server:  0
# customer:  11
# event_type  A  event: (28, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E08C8>)
# -------------event-------------
# time:  38
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x0000000008803908>
# customer:  11
# event_type  A  event: (28, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x0000000008810288>)
# -------------event-------------
# time:  34
# type:  D
# phase:  2
# server:  <server_class.Server instance at 0x00000000088083C8>
# customer:  6
# event_type  S  event: (30, 'S', 0, 0)
# (0, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000088031C8>)
# (4, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000088031C8>)
# (4, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000088031C8>)
# (4, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FADC8>)
# (7, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FADC8>)
# (7, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FADC8>)
# (8, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAD08>)
# (9, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAE08>)
# (10, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000088031C8>)
# (11, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FAD08>)
# (11, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAD08>)
# (12, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAC88>)
# (12, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FA408>)
# (14, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008810288>)
# (14, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FAC88>)
# (14, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAC88>)
# (15, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAD48>)
# (16, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087FADC8>)
# (16, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000087FAE08>)
# (16, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAE08>)
# (17, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0C88>)
# (17, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0D08>)
# (18, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x0000000008810288>)
# (18, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x0000000008810288>)
# (19, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E08C8>)
# (19, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E0D08>)
# (19, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0D08>)
# (19, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0E08>)
# (19, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000087FAD48>)
# (19, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FA408>)
# (19, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAD48>)
# (19, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FA408>)
# (20, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0108>)
# (20, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x00000000087FAC88>)
# (21, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E08C8>)
# (21, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E08C8>)
# (21, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x0000000008810288>)
# (21, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880F888>)
# (21, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0F08>)
# (22, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000087E0C88>)
# (22, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880FA48>)
# (22, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0C88>)
# (23, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E0E08>)
# (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880F808>)
# (23, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0E08>)
# (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880F7C8>)
# (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A00BC8>)
# (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880DF88>)
# (23, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A00E88>)
# (24, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x000000000880FA48>)
# (24, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x000000000880DAC8>)
# (24, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880FA48>)
# (24, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A00C08>)
# (24, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x00000000087E08C8>)
# (25, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087FAD08>)
# (25, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x000000000880F888>)
# (25, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880F888>)
# (25, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087E0E08>)
# (25, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x000000000880F7C8>)
# (25, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880F7C8>)
# (25, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x0000000008A00BC8>)
# (25, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x0000000008A00BC8>)
# (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E02C8>)
# (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FA3C8>)
# (26, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x000000000880DAC8>)
# (26, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880DAC8>)
# (26, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E0F08>)
# (26, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0F08>)
# (26, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E0108>)
# (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A05748>)
# (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08248>)
# (26, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E0E88>)
# (26, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E0108>)
# (27, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087E0C88>)
# (27, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x00000000087FAD48>)
# (27, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08408>)
# (27, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08488>)
# (28, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087E0D08>)
# (28, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x0000000008A00C08>)
# (28, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x0000000008A00C08>)
# (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08188>)
# (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08308>)
# (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08388>)
# (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08508>)
# (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08588>)
# (28, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A086C8>)
# (29, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x000000000880F808>)
# (29, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x0000000008803908>, <entity_class.Entity instance at 0x000000000880F888>)
# (29, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087E02C8>)
# (29, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E02C8>)
# (29, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08648>)
# (29, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x000000000880F808>)
# (29, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008A08788>)
# (10, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000088031C8>)
# (14, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FADC8>)
# (17, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000088031C8>)
# (17, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000088031C8>)
# (17, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FADC8>)
# (17, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FADC8>)
# (18, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087FAC88>)
# (20, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000088031C8>)
# (22, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x0000000008810288>)
# (22, 'A', <phase_class.Phase instance at 0x00000000088082C8>, 0, <entity_class.Entity instance at 0x00000000087E08C8>)
# (25, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x00000000087FAC88>)
# (25, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087FAC88>)
# (25, 'D', <phase_class.Phase instance at 0x0000000008803D88>, <server_class.Server instance at 0x00000000088083C8>, <entity_class.Entity instance at 0x00000000087FADC8>)
# (28, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x0000000008808548>, <entity_class.Entity instance at 0x0000000008810288>)
# (28, 'D', <phase_class.Phase instance at 0x00000000088082C8>, <server_class.Server instance at 0x000000000881CBC8>, <entity_class.Entity instance at 0x00000000087E08C8>)
# (28, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x00000000087E08C8>)
# (28, 'A', <phase_class.Phase instance at 0x0000000008803D88>, 0, <entity_class.Entity instance at 0x0000000008810288>)
# w_n : 2
# l_t : 30
